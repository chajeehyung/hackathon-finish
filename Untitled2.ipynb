# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
chromedriver_dir = '/home/chajeehyung/chajeehyung/projects/django/hackathon/Chromedriver/chromedriver'
options = webdriver.ChromeOptions()
# options.add_argument('headless')
driver = webdriver.Chrome(chromedriver_dir, chrome_options=options)
# Out:
# /home/chajeehyung/.pyenv/versions/3.6.6/envs/fc-hackathon/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys

# %%
url = 'https://www.google.co.kr/search?q=박보영&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjb45_Y-dfeAhUDZt4KHdzeC0QQ_AUIDigB&biw=1853&bih=355'

# %%
driver.get(url)

# %%
# //*[@id="irc_cc"]/div[2]/div[1]/div[2]/div[1]/a/img
# //*[@id="irc_cc"]/div[3]/div[1]/div[2]/div[1]/a/img

# %%
# driver.find_element_by_class_name('rg_ic').get_attribute('outerHTML')
driver.find
# Out:
# '<img class="rg_ic rg_i" data-src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSeeTKjJmKtk5PhX9S_juaht4-x3DKQ8q-OgcVbkuxsA79FVci4" jsaction="load:str.tbn" alt="박보영에 대한 이미지 검색결과" onload="typeof google===\'object\'&amp;&amp;google.aft&amp;&amp;google.aft(this)" style="width: 161px; height: 242px; margin-left: 4px; margin-right: 5px; margin-top: 0px;">'

# %%
open('pby_detail.html', 'wt').write(response.text)
# Out:
# 41041

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8877808c013c> in <module>
# ----> 1 response = driver.get(url)
#
# TypeError: get() missing 1 required positional argument: 'url'

# %%
html = open('pby_detail.html', 'rt').read()
soup = BeautifulSoup(html, 'lxml')

# %%
soup.find_all('img')
# Out:
# [<img alt="" height="23" onclick="(function(){var text_input_assistant_js='/textinputassistant/11/ko_tia.js';var s = document.createElement('script');s.src = text_input_assistant_js;(document.getElementById('xjsc')|| document.body).appendChild(s);})();" src="/textinputassistant/tia.png" style="padding-top:2px" width="27"/>,
#  <img alt="박보영에 대한 이미지 검색결과" height="141" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFN-Twy7vj2Y9wM0ofh4pdc6K9I63VcLQgg2ovfHI51SDZx8cG2crYgnpo" width="102"/>,
#  <img alt="박보영에 대한 이미지 검색결과" height="90" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQY4T0GCmdEIuepU1aQnQMlzAgfvaV_GOVnCs8w4UxN-8CtCpPKCocFOMAL" width="133"/>,
#  <img alt="박보영에 대한 이미지 검색결과" height="97" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSYEAwRYatYtZBT3eIZ05YV_KDO61JHfiXiEDuY275otqikoKEm7wOILDtE" width="149"/>,
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
